# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.cm as cm
import logging
import sys
sys.path.insert(0,'./fortran_package/') # carico la directory con i pacchetti
import maps
import ComputeLE
import numpy as np
import os

# %%
def main():
    fig = plt.figure(figsize=(15,15))
    ax1 = fig.add_subplot(111, projection='3d')
#     ax2 = fig.add_subplot(122, projection='3d')
    ax1.set_axis_off()
    # Parameters
    a = np.array([[1,    1.09, 1.52, 0   ],
                  [0,    1,    0.44, 1.36],
                  [2.33, 0,    1,    0.47],
                  [1.21, 0.51, 0.35, 1   ]])
    r = np.array([1, 0.72,     1.53, 1.27])
    param = [a, r]
    n = 100000
    t = np.linspace(0, 10000, n)
    t1 = np.linspace(10000, 15000, n)
    # Inital Values
    init = np.array([0.3, 0.3, 0.3, 0.1])
    x = np.ones((n, 4))*init
    x = ComputeLE.motion(t, x, a, r)
    x[0] = x[-1]
    x = ComputeLE.motion(t1, x, a, r)
    xx = x[:,0]
    yy = x[:,1]
    zz = x[:,2]
    ww = x[:,3]
    ax1.scatter(xx, yy, zz, s = 0.01, alpha=0.5) 
#     ax2.scatter(x, y, z, s = 0.001)  

    ax1.set_xlabel('x')
#     ax2.set_xlabel('x')

    ax1.set_ylabel('y')
#     ax2.set_ylabel('y')

    ax1.set_zlabel('z')
#     ax2.set_zlabel('z')

    ax1.xaxis.pane.fill = False
    ax1.yaxis.pane.fill = False
    ax1.zaxis.pane.fill = False

    # Now set color to white (or whatever is "invisible")
    ax1.xaxis.pane.set_edgecolor('w')
    ax1.yaxis.pane.set_edgecolor('w')
    ax1.zaxis.pane.set_edgecolor('w')

#     ax2.xaxis.pane.fill = False
#     ax2.yaxis.pane.fill = False
#     ax2.zaxis.pane.fill = False

#     # Now set color to white (or whatever is "invisible")
#     ax2.xaxis.pane.set_edgecolor('w')
#     ax2.yaxis.pane.set_edgecolor('w')
#     ax2.zaxis.pane.set_edgecolor('w')
    
    ax1.view_init(30, 45)
#     ax2.view_init(80, 90)
    plt.tight_layout()
    plt.savefig('../Latex/figures/LV_copertina.png', dpi = 300)
    plt.show()
main()

# %%
print('ciao')
